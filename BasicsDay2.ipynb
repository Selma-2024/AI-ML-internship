# %% [markdown]
# # ***STRINGS***

# %%
print("hello world") #notating with ""
print('The baby said')#notating with ''
# Out:
# hello world
# The baby said

# %% [markdown]
# **\n**

# %%
print('There were new people. \nMainly in the city')
print("That had came because of the war")
# Out:
# There were new people.
# Mainly in the city
# That had came because of the war

# %% [markdown]
# **len()**

# %%
s="linear regression classification"
print(len(s))
# Out:
# 32

# %%
print(s[0])
print(s[22])
print(s[31])
# Out:
# l
# s
# n

# %%
print(s[-1])
print(s[-3])
# Out:
# n
# i

# %% [markdown]
# **Slicing**

# %%
print(s[:13])
# Out:
# linear regres

# %%
print(s[10:])
# Out:
# ression classification

# %%
print(s[1:3]) #last letter won't come as it have to denote the letter
+1
# Out:
# in

# %%
print(s[:])
# Out:
# linear regression classification

# %%
print(s[-6:])
print(s[-6:-1])
# Out:
# cation
# catio

# %% [markdown]
# **step size**

# %%
print(s[::1])
# Out:
# linear regression classification

# %%
print(s[::2])
# Out:
# lna ersincasfcto

# %%
u="malayalam"
print(u[::2])
# Out:
# mlylm

# %% [markdown]
# ***-special case***

# %%
print(s[7::2]) #stepping 2 letters , from 7Th to the last
# Out:
# rgeso lsiiain

# %% [markdown]
# ***-reverse string***

# %%
print(s[::-1])
# Out:
# noitacifissalc noisserger raenil

# %% [markdown]
# # **Adding- letters , integers**

# %%
d='10'
e='200'
print(d+e)
# Out:
# 10200

# %%
d=20
e=30
print(d+e)
# Out:
# 50

# %%
d="solve"
e="the"
f="problem"
print(d+e+f)
# Out:
# solvetheproblem

# %% [markdown]
# # **Functions and Methods**

# %%
name="supervised learning"
print(name)
# Out:
# supervised learning

# %% [markdown]
# ***-lower()***

# %%
print(name.lower())
# Out:
# supervised learning

# %% [markdown]
# ***-upper()***

# %%
print(name.upper())
# Out:
# SUPERVISED LEARNING

# %%
n="Supervised Learning"
print(n.lower())
# Out:
# supervised learning

# %% [markdown]
# ***-count()***

# %%
print(n.count('i'))
# Out:
# 2

# %%
p='perform the performance'
print(p.count('pe'))
# Out:
# 2

# %%
print(p.count('s'))
# Out:
# 0

# %% [markdown]
# ***-find()***

# %%
print(p.find('s'))
# Out:
# -1

# %%
print(p.find('m'))
# Out:
# 6

# %% [markdown]
# ***-len()***

# %%
print(len(name))
print(len(p))
# Out:
# 19
# 23

# %% [markdown]
# ***-replace()***

# %%
start='Turing Test'
print(start.replace(' ','_'))
# Out:
# Turing_Test

# %% [markdown]
# ***-print(f'..')***

# %%
first_name="Issac"
last_name="Newton"
print(f'The person {first_name} {last_name} was a well known scientist')
# Out:
# The person Issac Newton was a well known scientist

# %% [markdown]
# # TASKS

# %% [markdown]
# **Create a program that stores your name in a string and prints it in uppercase.**

# %%
nm="Selma Anna Saju"
print(nm.upper())
# Out:
# SELMA ANNA SAJU

# %% [markdown]
# **Write a program to store a sentence and print only the first character and last character.**

# %%
sent="Polynomial Regression"
print(sent[0])
print(sent[-1])
# Out:
# P
# n

# %% [markdown]
# **Create a string "Python Programming" and print the total number of characters using a string method.**

# %%
p="Python Programming"
print(len(p))
# Out:
# 18

# %% [markdown]
# **Store "hello world" in a variable and print it with the first letter of each word capitalized.**

# %%
var="hello world"
print(var.title()) # title() used to make capital letter of each word
# Out:
# Hello World

# %% [markdown]
# **Write a program to replace all spaces in a sentence with -**

# %%
spc="Large Language Models"
print(spc.replace(' ','-'))
# Out:
# Large-Language-Models

# %% [markdown]
# **Create a string "banana" and print how many times the letter "a" appears.**

# %%
str="banana"
print(str.count('a'))
# Out:
# 3

# %% [markdown]
# **Store your favorite movie name in a string and print it in lowercase.**

# %%
mov="The Summer I TURNED PRETTY"
print(mov.lower())
# Out:
# the summer i turned pretty

# %% [markdown]
# **Write a program to check whether the word "Python" exists inside the sentence "I am learning Python today".**

# %%
exst="I am leaning Python today"
print(exst.find("Python"))
print("Python" in exst)
# Out:
# 13
# True

# %% [markdown]
# **Create a string with extra spaces at the beginning and end, then remove the spaces and print the result.**

# %%
spaced_string = "   A long time ago initial stges of AI existed   "
print(f"Original: '{spaced_string}'")
print(f"Stripped: '{spaced_string.strip()}'") #function strip()- used
#lstrip() - leading space
#rstrip() - trailing spaces
# Out:
# Original: '   A long time ago initial stges of AI existed   '
# Stripped: 'A long time ago initial stges of AI existed'

# %% [markdown]
# **Store "apple,mango,orange" in a string and split it into separate fruits using a string method.**

# %%
fruits= "apple,mango,orange"
fruit_list = fruits.split(',') #str.split()- used to split from the particular point
print(fruit_list)
# Out:
# ['apple', 'mango', 'orange']
