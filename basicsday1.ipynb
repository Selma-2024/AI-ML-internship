# %%
x=5

# %%
print(x)
# Out:
# 5

# %% [markdown]
# ## ***Relational operation***

# %%
#relational operation
x=10
y=20
print(x>y)
print(y>x)
print(x!=y)
print(x==y)
# Out:
# False
# True
# True
# False

# %% [markdown]
# # ***Type Casting***

# %%
#typecasting
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
#type of the particular
x='wondering'
print(type(x))
# Out:
# <class 'str'>

# %%
#type
a='10'
print(type(a))
# Out:
# <class 'str'>

# %%
#type
a=input()
print(a)
print(type(a))
# Out:
# 10
# 10
# <class 'str'>

# %%
#typecasting - conversion
a=int(input())
print(a)
print(type(a))
# Out:
# 10
# 10
# <class 'int'>

# %%
a=input()
print(a)
print(type(a))
# Out:
# ai internship
# ai internship
# <class 'str'>

# %% [markdown]
# # ***Arithmetic operation***

# %%
#arithmetic operations

a=10
b=20

print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 30
# -10
# 200
# 0.5

# %%
#concatinating
a='adding'
b='concat'
print(a + b)
# Out:
# addingconcat

# %% [markdown]
# # ***Data Types***

# %%
print(type(0.11))
print(type(True))
print(type(13))
print(type("whistling"))
print(type(0.114552))
print(type('C'))
# Out:
# <class 'float'>
# <class 'bool'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
